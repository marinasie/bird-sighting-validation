# %% [markdown]
# # Merge swiss and german datasets
# We aligned both datasets to create a consistent master dataset. <br><br>
# Important decisions we made: <br>
# - Remove `estimation_code` feature from the german dataset as it is not given in the swiss dataset and is not considered crucial for our use case.
# - Keep `altitude` even though all german entries are zero. -> Maybe discuss this further.
# - Align feature names
# - Align dtypes
# - Align date formats
# - Align precisions; drop some precisions in german dataset as they are not in the datafield description and only a minority.
#
# You can download the master dataset, the swiss dataset and the german dataset [here](https://drive.google.com/drive/folders/1R9VHEs6nq8ogPYSSp8IfSbkFWFAoyhm8?usp=sharing).<br>
# Alternatively, run the code by yourself to create the master dataset; please provide your data paths in chapter 1.

# %%
import pandas as pd

# %% [markdown]
# ## 1 - Load data

# %%
data_path_ch = '/Users/marinasiebold/Library/Mobile Documents/com~apple~CloudDocs/Studium/Bird_Research/01_Data/birds_ch_2018-2022.csv'  # Provide data path of swiss dataset
data_path_de = '/Users/marinasiebold/Library/Mobile Documents/com~apple~CloudDocs/Studium/Bird_Research/01_Data/birds_de_2018-2022.csv'  # Provide data path of german dataset
data_path_master = '/Users/marinasiebold/Library/Mobile Documents/com~apple~CloudDocs/Studium/Bird_Research/01_Data/master_bird_data.csv'  # Provide data path where merged dataset shall be saved

# %%
ch_data = pd.read_csv(data_path_ch, delimiter=';')
ch_data.head()
# Out:
#    ID_SIGHTING  ID_SPECIES  NAME_SPECIES        DATE    TIMING  COORD_LAT
# 0     14731644       371.0     Blaumeise  2018-01-21       NaN  46.217211  \
# 1     15360340       361.0     Saatkrähe  2018-03-24  10:41:00  46.923721
# 2     15360731       358.0    Rabenkrähe  2018-03-24       NaN  46.887983
# 3     15360732       495.0  Feldsperling  2018-03-24       NaN  46.887983
# 4     15360733       518.0      Buchfink  2018-03-24       NaN  46.887983
#
#    COORD_LON             PRECISION  ALTITUDE  TOTAL_COUNT  ATLAS_CODE_CH
# 0   7.582658  Exakte Lokalisierung      1150          1.0              0  \
# 1   7.481304  Exakte Lokalisierung       510          NaN              0
# 2   7.545741                   Ort       520          NaN              0
# 3   7.545741                   Ort       520          NaN              0
# 4   7.545741                   Ort       520          NaN              0
#
#    ID_OBSERVER
# 0      11750.0
# 1       2246.0
# 2       3539.0
# 3       3539.0
# 4       3539.0

# %%
de_data = pd.read_csv(data_path_de)
de_data.head()
# Out:
#    id_sighting  id_species name_species        date timing  coord_lat
# 0     29666944         119   Reiherente  01.01.2018    NaN   53.15776  \
# 1     29666945         141   Gänsesäger  01.01.2018    NaN   53.15776
# 2     29666946          24     Kormoran  01.01.2018  04:00   53.15776
# 3     29666947         205    Blässhuhn  01.01.2018    NaN   53.15776
# 4     29666948         309  Ringeltaube  01.01.2018    NaN   53.15776
#
#    coord_lon precision estimation_code  altitude  total_count altas_code
# 0   8.676993     place     EXACT_VALUE         0           24        NaN  \
# 1   8.676993     place     EXACT_VALUE         0            1        NaN
# 2   8.676993     place      ESTIMATION         0          240        NaN
# 3   8.676993     place     EXACT_VALUE         0           13        NaN
# 4   8.676993     place     EXACT_VALUE         0            2        NaN
#
#    beobachter
# 0       37718
# 1       37718
# 2       37718
# 3       37718
# 4       37718

# %% [markdown]
# ## 2 - Merge datasets

# %% [markdown]
# ### Align features
# `estimation_code` holds information if the birdo count is an exact value or an estimation. As it is only present in the swiss dataset, it is dropped.

# %%
de_data.drop(columns='estimation_code', inplace=True)

# %% [markdown]
# ### Align feature names
# Some columns represent the same features but have different names or typos.

# %%
ch_data.columns = ch_data.columns.str.lower()
ch_data.rename({'atlas_code_ch': 'atlas_code'}, axis='columns', inplace=True)
de_data.rename({'beobachter':'id_observer', 'altas_code': 'atlas_code'}, axis='columns', inplace=True)

# %% [markdown]
# ### Align dtypes
# German data uses *float* for `id_species`, `total_count` and `id_observer`. <br>
# Swiss data uses *int*. <br><br>
# Swiss scheme is used as there are no decimals necessary for these features.

# %%
df = pd.DataFrame(columns=['ch dtype', 'de dtype'])
for col in ch_data.columns:
    df.loc[col] = [ch_data[col].dtype, de_data[col].dtype]
df
# Out:
#              ch dtype de dtype
# id_sighting     int64    int64
# id_species    float64    int64
# name_species   object   object
# date           object   object
# timing         object   object
# coord_lat     float64  float64
# coord_lon     float64  float64
# precision      object   object
# altitude        int64    int64
# total_count   float64    int64
# atlas_code      int64   object
# id_observer   float64    int64

# %%
ch_data.id_species = ch_data.id_species.astype('Int64')
ch_data.total_count = ch_data.total_count.astype('Int64')
ch_data.id_observer = ch_data.id_observer.astype('Int64')

de_data.id_species = de_data.id_species.astype('Int64')
de_data.total_count = de_data.total_count.astype('Int64')
de_data.id_observer = de_data.id_observer.astype('Int64')

# %% [markdown]
# ### Align date format
# Swiss data uses *yyyy-mm-dd* <br>
# German data uses *dd.mm.yyyy* <br><br>
# Swiss scheme is used as it is more common.

# %%
def change_dateformat(date):
    d_m_y = date.split('.')
    y_m_d = '{}-{}-{}'.format(d_m_y[2], d_m_y[1], d_m_y[0])
    return y_m_d

de_data.date = de_data.date.apply(change_dateformat)
de_data.head()
# Out:
#    id_sighting  id_species name_species        date timing  coord_lat
# 0     29666944         119   Reiherente  2018-01-01    NaN   53.15776  \
# 1     29666945         141   Gänsesäger  2018-01-01    NaN   53.15776
# 2     29666946          24     Kormoran  2018-01-01  04:00   53.15776
# 3     29666947         205    Blässhuhn  2018-01-01    NaN   53.15776
# 4     29666948         309  Ringeltaube  2018-01-01    NaN   53.15776
#
#    coord_lon precision  altitude  total_count atlas_code  id_observer
# 0   8.676993     place         0           24        NaN        37718
# 1   8.676993     place         0            1        NaN        37718
# 2   8.676993     place         0          240        NaN        37718
# 3   8.676993     place         0           13        NaN        37718
# 4   8.676993     place         0            2        NaN        37718

# %% [markdown]
# ### Align precisions
# According to the datafield description by @Johannes, the following upholds:
# - *precise* = *Exakte Lokalisierung*
# - *square* = *Kilometerquadrat*
# - *place* = *Ort*<br><br>
#
# The swiss descriptions are adjusted accordingly to the english counterparts.<br>
# All other values in the german dataset are dropped as they have very little occurences and are not present in the swiss dataset or in the datafield description (see below).

# %%
# Before: Occurences of all precisions in both datasets
print('\033[1m'+'German precision occurences:\n', '\033[0m', de_data.groupby('precision').size())
print('\033[1m'+'\nSwiss precision occurences:\n', '\033[0m', ch_data.groupby('precision').size())
# Out:
# German precision occurences:
#   precision
# municipality               6
# place               10012712
# polygone                   4
# polygone_precise           8
# precise             22903811
# square               7186252
# subplace                   2
# transect_precise          53
# dtype: int64
#
# Swiss precision occurences:
#   precision
# Exakte Lokalisierung    4753055
# Kilometerquadrat        3176584
# Ort                     1993236
# dtype: int64

# %%
# Replace swiss precisions with english counterparts
precisions = {'Exakte Lokalisierung': 'precise', 
              'Kilometerquadrat': 'square', 
              'Ort': 'place'}
ch_data.precision = ch_data.precision.map(precisions)

# %%
# drop all minority precisions in german dataset
precisions_to_drop = 'municipality|polygone|polygone_precise|subplace|transect_precise'
de_data.drop(de_data[de_data.precision.str.contains(precisions_to_drop)].index, inplace=True)

# %%
# After: Aligned and cleaned precision occurences
print('\033[1m'+'German precision occurences:\n', '\033[0m', de_data.groupby('precision').size())
print('\033[1m'+'\nSwiss precision occurences:\n', '\033[0m', ch_data.groupby('precision').size())
# Out:
# German precision occurences:
#   precision
# place      10012712
# precise    22903811
# square      7186252
# dtype: int64
#
# Swiss precision occurences:
#   precision
# place      1993236
# precise    4753055
# square     3176584
# dtype: int64

# %% [markdown]
# #### Align bird names
# Many bird species have different names in both datasets. However, the ID is the same.<br>
# Based on the species ID, all swiss bird names are replaced by their german counterpart. If a bird species is only present in the swiss dataset, its name stays as-is.

# %% [markdown]
# #### Comparison of bird names in Germany and bird names in Switzerland

# %%
def highlight_rows(row):
    german = row.loc['German name']
    swiss = row.loc['Swiss name']
    color = ''
    if german != swiss and swiss != '-' and german != '-':
        color = 'red' # Red
    return ['color: {}'.format(color) for r in row]

# %%
# Create a dicts  with species_id as keys and species_names as values {<species_id>: <species_name>}
german_species_map = dict(zip(de_data.id_species, de_data.name_species))
swiss_species_map = dict(zip(ch_data.id_species, ch_data.name_species))

# Create side-by-side comparison view
species_name_comparison = pd.DataFrame({'German name': pd.Series(german_species_map).sort_index(),
                                        'Swiss name': pd.Series(swiss_species_map).sort_index()}).fillna('-')
species_name_comparison.style.apply(highlight_rows, axis=1)
# Out:
# <style type="text/css">
# #T_6ca4a_row0_col0, #T_6ca4a_row0_col1, #T_6ca4a_row1_col0, #T_6ca4a_row1_col1, #T_6ca4a_row2_col0, #T_6ca4a_row2_col1, #T_6ca4a_row3_col0, #T_6ca4a_row3_col1, #T_6ca4a_row4_col0, #T_6ca4a_row4_col1, #T_6ca4a_row5_col0, #T_6ca4a_row5_col1, #T_6ca4a_row6_col0, #T_6ca4a_row6_col1, #T_6ca4a_row7_col0, #T_6ca4a_row7_col1, #T_6ca4a_row8_col0, #T_6ca4a_row8_col1, #T_6ca4a_row9_col0, #T_6ca4a_row9_col1, #T_6ca4a_row10_col0, #T_6ca4a_row10_col1, #T_6ca4a_row11_col0, #T_6ca4a_row11_col1, #T_6ca4a_row13_col0, #T_6ca4a_row13_col1, #T_6ca4a_row14_col0, #T_6ca4a_row14_col1, #T_6ca4a_row15_col0, #T_6ca4a_row15_col1, #T_6ca4a_row16_col0, #T_6ca4a_row16_col1, #T_6ca4a_row17_col0, #T_6ca4a_row17_col1, #T_6ca4a_row18_col0, #T_6ca4a_row18_col1, #T_6ca4a_row19_col0, #T_6ca4a_row19_col1, #T_6ca4a_row20_col0, #T_6ca4a_row20_col1, #T_6ca4a_row21_col0, #T_6ca4a_row21_col1, #T_6ca4a_row22_col0, #T_6ca4a_row22_col1, #T_6ca4a_row23_col0, #T_6ca4a_row23_col1, #T_6ca4a_row24_col0, #T_6ca4a_row24_col1, #T_6ca4a_row25_col0, #T_6ca4a_row25_col1, #T_6ca4a_row26_col0, #T_6ca4a_row26_col1, #T_6ca4a_row27_col0, #T_6ca4a_row27_col1, #T_6ca4a_row28_col0, #T_6ca4a_row28_col1, #T_6ca4a_row29_col0, #T_6ca4a_row29_col1, #T_6ca4a_row31_col0, #T_6ca4a_row31_col1, #T_6ca4a_row32_col0, #T_6ca4a_row32_col1, #T_6ca4a_row33_col0, #T_6ca4a_row33_col1, #T_6ca4a_row34_col0, #T_6ca4a_row34_col1, #T_6ca4a_row35_col0, #T_6ca4a_row35_col1, #T_6ca4a_row36_col0, #T_6ca4a_row36_col1, #T_6ca4a_row38_col0, #T_6ca4a_row38_col1, #T_6ca4a_row39_col0, #T_6ca4a_row39_col1, #T_6ca4a_row41_col0, #T_6ca4a_row41_col1, #T_6ca4a_row42_col0, #T_6ca4a_row42_col1, #T_6ca4a_row43_col0, #T_6ca4a_row43_col1, #T_6ca4a_row45_col0, #T_6ca4a_row45_col1, #T_6ca4a_row46_col0, #T_6ca4a_row46_col1, #T_6ca4a_row47_col0, #T_6ca4a_row47_col1, #T_6ca4a_row48_col0, #T_6ca4a_row48_col1, #T_6ca4a_row49_col0, #T_6ca4a_row49_col1, #T_6ca4a_row50_col0, #T_6ca4a_row50_col1, #T_6ca4a_row51_col0, #T_6ca4a_row51_col1, #T_6ca4a_row53_col0, #T_6ca4a_row53_col1, #T_6ca4a_row54_col0, #T_6ca4a_row54_col1, #T_6ca4a_row56_col0, #T_6ca4a_row56_col1, #T_6ca4a_row58_col0, #T_6ca4a_row58_col1, #T_6ca4a_row61_col0, #T_6ca4a_row61_col1, #T_6ca4a_row62_col0, #T_6ca4a_row62_col1, #T_6ca4a_row63_col0, #T_6ca4a_row63_col1, #T_6ca4a_row65_col0, #T_6ca4a_row65_col1, #T_6ca4a_row66_col0, #T_6ca4a_row66_col1, #T_6ca4a_row69_col0, #T_6ca4a_row69_col1, #T_6ca4a_row70_col0, #T_6ca4a_row70_col1, #T_6ca4a_row71_col0, #T_6ca4a_row71_col1, #T_6ca4a_row73_col0, #T_6ca4a_row73_col1, #T_6ca4a_row74_col0, #T_6ca4a_row74_col1, #T_6ca4a_row75_col0, #T_6ca4a_row75_col1, #T_6ca4a_row76_col0, #T_6ca4a_row76_col1, #T_6ca4a_row77_col0, #T_6ca4a_row77_col1, #T_6ca4a_row78_col0, #T_6ca4a_row78_col1, #T_6ca4a_row79_col0, #T_6ca4a_row79_col1, #T_6ca4a_row80_col0, #T_6ca4a_row80_col1, #T_6ca4a_row81_col0, #T_6ca4a_row81_col1, #T_6ca4a_row82_col0, #T_6ca4a_row82_col1, #T_6ca4a_row83_col0, #T_6ca4a_row83_col1, #T_6ca4a_row84_col0, #T_6ca4a_row84_col1, #T_6ca4a_row85_col0, #T_6ca4a_row85_col1, #T_6ca4a_row86_col0, #T_6ca4a_row86_col1, #T_6ca4a_row88_col0, #T_6ca4a_row88_col1, #T_6ca4a_row89_col0, #T_6ca4a_row89_col1, #T_6ca4a_row91_col0, #T_6ca4a_row91_col1, #T_6ca4a_row92_col0, #T_6ca4a_row92_col1, #T_6ca4a_row93_col0, #T_6ca4a_row93_col1, #T_6ca4a_row94_col0, #T_6ca4a_row94_col1, #T_6ca4a_row95_col0, #T_6ca4a_row95_col1, #T_6ca4a_row96_col0, #T_6ca4a_row96_col1, #T_6ca4a_row97_col0, #T_6ca4a_row97_col1, #T_6ca4a_row98_col0, #T_6ca4a_row98_col1, #T_6ca4a_row99_col0, #T_6ca4a_row99_col1, #T_6ca4a_row100_col0, #T_6ca4a_row100_col1, #T_6ca4a_row101_col0, #T_6ca4a_row101_col1, #T_6ca4a_row102_col0, #T_6ca4a_row102_col1, #T_6ca4a_row104_col0, #T_6ca4a_row104_col1, #T_6ca4a_row105_col0, #T_6ca4a_row105_col1, #T_6ca4a_row106_col0, #T_6ca4a_row106_col1, #T_6ca4a_row107_col0, #T_6ca4a_row107_col1, #T_6ca4a_row108_col0, #T_6ca4a_row108_col1, #T_6ca4a_row109_col0, #T_6ca4a_row109_col1, #T_6ca4a_row110_col0, #T_6ca4a_row110_col1, #T_6ca4a_row111_col0, #T_6ca4a_row111_col1, #T_6ca4a ...

# %% [markdown]
# #### Problem: Apparently, not all german id's == swiss id's

# %%
display(de_data[de_data.id_species==314].head())
display(ch_data[ch_data.id_species==314].head())
# Out:
#        id_sighting  id_species  name_species        date timing  coord_lat
# 5061      29652006         314  Schleiereule  2018-01-01    NaN  52.111929  \
# 8623      29774039         314  Schleiereule  2018-01-01    NaN  54.051124
# 23253     29648892         314  Schleiereule  2018-01-01    NaN  51.676494
# 28557     36335001         314  Schleiereule  2019-01-01    NaN  49.928015
# 29163     36465019         314  Schleiereule  2019-01-01    NaN  48.119890
#
#        coord_lon precision  altitude  total_count atlas_code  id_observer
# 5061    6.900061   precise         0            1        NaN        94465
# 8623    9.844217   precise         0            1        NaN       119330
# 23253   6.042677   precise         0            1        NaN        66634
# 28557  10.240481    square         0            1        NaN        38875
# 29163  10.507153    square         0            0        NaN        43461
#       id_sighting  id_species name_species        date timing  coord_lat
# 738      15563770         314      Kuckuck  2018-04-16    NaN  46.396284  \
# 747      15568002         314      Kuckuck  2018-04-17    NaN  46.981906
# 819      15585844         314      Kuckuck  2018-04-19    NaN  47.582410
# 901      15596605         314      Kuckuck  2018-04-21    NaN  47.630094
# 1043     15776702         314      Kuckuck  2018-05-14    NaN  46.504846
#
#       coord_lon precision  altitude  total_count  atlas_code  id_observer
# 738    6.902060     place       370            1           1          725
# 747    7.050892    square       430            1           3         9066
# 819    8.242828    square       320            2           3         2778
# 901    7.565012    square       270            1           1        14827
# 1043   8.943449    square       830            1           3        11944

# %% [markdown]
# #### Align bird names

# %%
# In swiss dataset: If a different bird name is used for the same species, replace it with respective german bird name
german_species_map = dict(zip(de_data.id_species, de_data.name_species))
ch_data.name_species = ch_data.id_species.map(german_species_map).fillna(ch_data.name_species)

# %% [markdown]
# ### Merge datasets

# %%
ch_data['country'] = 'ch'
de_data['country'] = 'de'

# %%
master_data = pd.concat([de_data, ch_data])
master_data.to_csv(data_path_master)

# %%
master_data.head()
# Out:
#    id_sighting  id_species name_species        date timing  coord_lat
# 0     29666944         119   Reiherente  2018-01-01    NaN   53.15776  \
# 1     29666945         141   Gänsesäger  2018-01-01    NaN   53.15776
# 2     29666946          24     Kormoran  2018-01-01  04:00   53.15776
# 3     29666947         205    Blässhuhn  2018-01-01    NaN   53.15776
# 4     29666948         309  Ringeltaube  2018-01-01    NaN   53.15776
#
#    coord_lon precision  altitude  total_count atlas_code  id_observer country
# 0   8.676993     place         0           24        NaN        37718      de
# 1   8.676993     place         0            1        NaN        37718      de
# 2   8.676993     place         0          240        NaN        37718      de
# 3   8.676993     place         0           13        NaN        37718      de
# 4   8.676993     place         0            2        NaN        37718      de

# %%
master_data.dtypes
# Out:
# id_sighting       int64
# id_species        Int64
# name_species     object
# date             object
# timing           object
# coord_lat       float64
# coord_lon       float64
# precision        object
# altitude          int64
# total_count       Int64
# atlas_code       object
# id_observer       Int64
# dtype: object
